# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_excel(r"FANCY BASE REPORT/lattest_Base_Report WITHOUT NULL VALUES.xlsx")

# %%
data
# Out:
#          Shape  From Size Clarity Color    Cut  Fluor   Current   9_2   5_2  \
# 0      CUSHION        0.7    VVS1     D  VGOOD    NONE     66.0  66.0  67.0
# 1      CUSHION        0.7    VVS1     D  VGOOD   FAINT     73.5  73.5  73.5
# 2      CUSHION        0.7    VVS1     D  VGOOD  MEDIUM     77.5  77.5  78.5
# 3      CUSHION        0.7    VVS1     D  VGOOD  STRONG     81.5  81.5  82.5
# 4      CUSHION        0.7    VVS1     D   GOOD    NONE     69.0  69.0  69.0
# ...        ...        ...     ...   ...    ...     ...      ...   ...   ...
# 27692  RADIANT        2.7     SI2     H  VGOOD  STRONG     61.0  61.0  61.0
# 27693  RADIANT        2.7     SI2     I  VGOOD    NONE     46.0  46.0  46.0
# 27694  RADIANT        2.7     SI2     I  VGOOD   FAINT     50.0  50.0  50.0
# 27695  RADIANT        2.7     SI2     I  VGOOD  MEDIUM     57.0  57.0  57.0
# 27696  RADIANT        2.7     SI2     I  VGOOD  STRONG     61.0  61.0  61.0
#
#        29_1  ...  19th  19th_pcs  20th  20th_pcs  Avg5  Avg10  Avg25  Avg35  \
# 0      67.0  ...   0.0         0   0.0         0  71.6   69.9  64.08  62.33
# 1      73.5  ...   0.0         0   0.0         0  74.4   74.0  72.44  70.74
# 2      78.5  ...  32.0         1   0.0         2  75.4   75.2  74.16  73.26
# 3      82.5  ...  47.0         1  32.0         1  75.4   75.2  74.40  73.69
# 4      69.0  ...   0.0         0   0.0         0  71.6   69.9  64.08  62.33
# ...     ...  ...   ...       ...   ...       ...   ...    ...    ...    ...
# 27692  58.0  ...   0.0         0   0.0         0  30.6   25.1  21.15  21.15
# 27693  46.0  ...   0.0         0   0.0         0  34.0   28.5  19.45  19.45
# 27694  50.0  ...   0.0         0   0.0         0  34.0   28.5  19.29  19.29
# 27695  55.0  ...   0.0         0   0.0         0  39.0   31.5  20.73  20.73
# 27696  58.0  ...   0.0         0   0.0         0  39.0   31.5  20.73  20.73
#
#        Avg50  TOTAL_PCS
# 0      62.33         27
# 1      66.40         48
# 2      71.40         67
# 3      72.02         72
# 4      62.33         27
# ...      ...        ...
# 27692  21.15         13
# 27693  19.45         20
# 27694  19.29         21
# 27695  20.73         22
# 27696  20.73         22
#
# [27697 rows x 60 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27697 entries, 0 to 27696
# Data columns (total 60 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Shape      27697 non-null  object
#  1   From Size  27697 non-null  float64
#  2   Clarity    27697 non-null  object
#  3   Color      27697 non-null  object
#  4   Cut        27697 non-null  object
#  5   Fluor      27697 non-null  object
#  6   Current    27697 non-null  float64
#  7   9_2        27697 non-null  float64
#  8   5_2        27697 non-null  float64
#  9   29_1       27697 non-null  float64
#  10  22_1       27697 non-null  float64
#  11  15_1       27697 non-null  float64
#  12  8_1        27697 non-null  float64
#  13  1_1        27697 non-null  float64
#  14  1st        27697 non-null  float64
#  15  1st_pcs    27697 non-null  int64
#  16  2nd        27697 non-null  float64
#  17  2nd_pcs    27697 non-null  int64
#  18  3rd        27697 non-null  float64
#  19  3rd_pcs    27697 non-null  int64
#  20  4th        27697 non-null  float64
#  21  4th_pcs    27697 non-null  int64
#  22  5th        27697 non-null  float64
#  23  5th_pcs    27697 non-null  int64
#  24  6th        27697 non-null  float64
#  25  6th_pcs    27697 non-null  int64
#  26  7th        27697 non-null  float64
#  27  7th_pcs    27697 non-null  int64
#  28  8th        27697 non-null  float64
#  29  8th_pcs    27697 non-null  int64
#  30  9th        27697 non-null  float64
#  31  9th_pcs    27697 non-null  int64
#  32  10th       27697 non-null  float64
#  33  10th_pcs   27697 non-null  int64
#  34  11th       27697 non-null  float64
#  35  11th_pcs   27697 non-null  int64
#  36  12th       27697 non-null  float64
#  37  12th_pcs   27697 non-null  int64
#  38  13th       27697 non-null  float64
#  39  13th_pcs   27697 non-null  int64
#  40  14th       27697 non-null  float64
#  41  14th_pcs   27697 non-null  int64
#  42  15th       27697 non-null  float64
#  43  15th_pcs   27697 non-null  int64
#  44  16th       27697 non-null  float64
#  45  16th_pcs   27697 non-null  int64
#  46  17th       27697 non-null  float64
#  47  17th_pcs   27697 non-null  int64
#  48  18th       27697 non-null  float64
#  49  18th_pcs   27697 non-null  int64
#  50  19th       27697 non-null  float64
#  51  19th_pcs   27697 non-null  int64
#  52  20th       27697 non-null  float64
#  53  20th_pcs   27697 non-null  int64
#  54  Avg5       27697 non-null  float64
#  55  Avg10      27697 non-null  float64
#  56  Avg25      27697 non-null  float64
#  57  Avg35      27697 non-null  float64
#  58  Avg50      27697 non-null  float64
#  59  TOTAL_PCS  27697 non-null  int64
# dtypes: float64(34), int64(21), object(5)
# memory usage: 12.7+ MB

# %%
categorical_columns = data.select_dtypes(include=['object']).columns.tolist()
categorical_columns
# Out:
# ['Shape', 'Clarity', 'Color', 'Cut', 'Fluor ']

# %%
def label_encode_categorical_columns(data_frame, categorical_columns):
    le = LabelEncoder()
    for column in categorical_columns:
        data_frame[column] = le.fit_transform(data_frame[column])
    return data_frame

# %%
df = label_encode_categorical_columns(data, categorical_columns)

# %%
df
# Out:
#        Shape  From Size  Clarity  Color  Cut  Fluor   Current   9_2   5_2  \
# 0          0        0.7        4      0    1       2     66.0  66.0  67.0
# 1          0        0.7        4      0    1       0     73.5  73.5  73.5
# 2          0        0.7        4      0    1       1     77.5  77.5  78.5
# 3          0        0.7        4      0    1       3     81.5  81.5  82.5
# 4          0        0.7        4      0    0       2     69.0  69.0  69.0
# ...      ...        ...      ...    ...  ...     ...      ...   ...   ...
# 27692      6        2.7        1      4    1       3     61.0  61.0  61.0
# 27693      6        2.7        1      5    1       2     46.0  46.0  46.0
# 27694      6        2.7        1      5    1       0     50.0  50.0  50.0
# 27695      6        2.7        1      5    1       1     57.0  57.0  57.0
# 27696      6        2.7        1      5    1       3     61.0  61.0  61.0
#
#        29_1  ...  19th  19th_pcs  20th  20th_pcs  Avg5  Avg10  Avg25  Avg35  \
# 0      67.0  ...   0.0         0   0.0         0  71.6   69.9  64.08  62.33
# 1      73.5  ...   0.0         0   0.0         0  74.4   74.0  72.44  70.74
# 2      78.5  ...  32.0         1   0.0         2  75.4   75.2  74.16  73.26
# 3      82.5  ...  47.0         1  32.0         1  75.4   75.2  74.40  73.69
# 4      69.0  ...   0.0         0   0.0         0  71.6   69.9  64.08  62.33
# ...     ...  ...   ...       ...   ...       ...   ...    ...    ...    ...
# 27692  58.0  ...   0.0         0   0.0         0  30.6   25.1  21.15  21.15
# 27693  46.0  ...   0.0         0   0.0         0  34.0   28.5  19.45  19.45
# 27694  50.0  ...   0.0         0   0.0         0  34.0   28.5  19.29  19.29
# 27695  55.0  ...   0.0         0   0.0         0  39.0   31.5  20.73  20.73
# 27696  58.0  ...   0.0         0   0.0         0  39.0   31.5  20.73  20.73
#
#        Avg50  TOTAL_PCS
# 0      62.33         27
# 1      66.40         48
# 2      71.40         67
# 3      72.02         72
# 4      62.33         27
# ...      ...        ...
# 27692  21.15         13
# 27693  19.45         20
# 27694  19.29         21
# 27695  20.73         22
# 27696  20.73         22
#
# [27697 rows x 60 columns]

# %%
X = df.drop(['Current'], axis = 1)
y = df['Current']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=108)

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (19387, 59)
# Shape of y_train: (19387,)
# Shape of X_test: (8310, 59)
# Shape of y_test: (8310,)

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('linear_regression', LinearRegression()),
#     ('random_forest', RandomForestRegressor())
#     ('decision_tree', DecisionTreeRegressor())
])

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('linear_regression', LinearRegression())])

# %%
predictions = pipeline.predict(X_test)

# %%
# Evaluate the performance using mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.9492574071382441

# %%
y_train
# Out:
# 8481     40.0
# 3837     55.0
# 12393    40.0
# 20065    47.5
# 18103    61.0
#          ...
# 26740    71.0
# 8786     43.0
# 13678    63.0
# 10699    44.0
# 8337     39.0
# Name: Current, Length: 19387, dtype: float64

# %%
predictions
# Out:
# array([42.62520261, 38.08740601, 74.48257528, ..., 58.33290594,
#        55.95525226, 62.05385203])
